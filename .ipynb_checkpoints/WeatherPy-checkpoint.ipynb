# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
name = []
clouds = []
country = []
date = []
humidity = []
lat = []
lon = []
temp_max = []
wind_speed = []

x = 1
for city in cities:
    weather_response = f"{url}&q={city}&units=imperial&APPID={api_key}"
    weather_response = requests.get(weather_response).json()
    print(f"Processing Record {x} of Set 1: {city}.")
    try:
        cit = weather_response["id"]
        name.append(weather_response["name"])
#         print(f"{city}  id: {cit}")      
        clouds.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lon.append(weather_response["coord"]["lon"])
        temp_max.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        x = x+1

    except KeyError:
        print(f"{city} not found")


print("done")
# Out:
# Processing Record 1 of Set 1: conde.
# Processing Record 2 of Set 1: avarua.
# Processing Record 3 of Set 1: yellowknife.
# Processing Record 4 of Set 1: pak phanang.
# Processing Record 5 of Set 1: coahuayana.
# Processing Record 6 of Set 1: half moon bay.
# Processing Record 7 of Set 1: port alfred.
# Processing Record 8 of Set 1: anderson.
# Processing Record 9 of Set 1: albany.
# Processing Record 10 of Set 1: belushya guba.
# belushya guba not found
# Processing Record 10 of Set 1: trincomalee.
# Processing Record 11 of Set 1: mehamn.
# Processing Record 12 of Set 1: magadan.
# Processing Record 13 of Set 1: cherskiy.
# Processing Record 14 of Set 1: ponta do sol.
# Processing Record 15 of Set 1: tuatapere.
# Processing Record 16 of Set 1: vaini.
# Processing Record 17 of Set 1: pevek.
# Processing Record 18 of Set 1: vostok.
# Processing Record 19 of Set 1: mugur-aksy.
# Processing Record 20 of Set 1: torbay.
# Processing Record 21 of Set 1: bundaberg.
# Processing Record 22 of Set 1: carnarvon.
# Processing Record 23 of Set 1: bredasdorp.
# Processing Record 24 of Set 1: sao joao da barra.
# Processing Record 25 of Set 1: kapaa.
# Processing Record 26 of Set 1: grindavik.
# Processing Record 27 of Set 1: amderma.
# amderma not found
# Processing Record 27 of Set 1: tasiilaq.
# Processing Record 28 of Set 1: vanatori.
# Processing Record 29 of Set 1: rikitea.
# Processing Record 30 of Set 1: senekal.
# Processing Record 31 of Set 1: ancud.
# Processing Record 32 of Set 1: camacha.
# Processing Record 33 of Set 1: necochea.
# Processing Record 34 of Set 1: husavik.
# Processing Record 35 of Set 1: ushuaia.
# Processing Record 36 of Set 1: davidson.
# Processing Record 37 of Set 1: inuvik.
# Processing Record 38 of Set 1: cape town.
# Processing Record 39 of Set 1: thompson.
# Processing Record 40 of Set 1: cockburn town.
# Processing Record 41 of Set 1: masjed-e soleyman.
# masjed-e soleyman not found
# Processing Record 41 of Set 1: puerto ayora.
# Processing Record 42 of Set 1: severo-kurilsk.
# Processing Record 43 of Set 1: murgab.
# Processing Record 44 of Set 1: revelstoke.
# Processing Record 45 of Set 1: airai.
# Processing Record 46 of Set 1: ondjiva.
# Processing Record 47 of Set 1: san pedro.
# Processing Record 48 of Set 1: mataura.
# Processing Record 49 of Set 1: punta arenas.
# Processing Record 50 of Set 1: pozo colorado.
# Processing Record 51 of Set 1: douentza.
# Processing Record 52 of Set 1: popondetta.
# Processing Record 53 of Set 1: castro.
# Processing Record 54 of Set 1: busselton.
# Processing Record 55 of Set 1: nizhneyansk.
# nizhneyansk not found
# Processing Record 55 of Set 1: pitanga.
# Processing Record 56 of Set 1: kutum.
# Processing Record 57 of Set 1: omsukchan.
# Processing Record 58 of Set 1: atuona.
# Processing Record 59 of Set 1: ihosy.
# Processing Record 60 of Set 1: bluff.
# Processing Record 61 of Set 1: butaritari.
# Processing Record 62 of Set 1: sanchez.
# Processing Record 63 of Set 1: hermanus.
# Processing Record 64 of Set 1: kawambwa.
# Processing Record 65 of Set 1: farragut.
# Processing Record 66 of Set 1: bafoulabe.
# Processing Record 67 of Set 1: takoradi.
# Processing Record 68 of Set 1: jamestown.
# Processing Record 69 of Set 1: chokurdakh.
# Processing Record 70 of Set 1: mareeba.
# Processing Record 71 of Set 1: nadvoitsy.
# Processing Record 72 of Set 1: fort wellington.
# Processing Record 73 of Set 1: vila velha.
# Processing Record 74 of Set 1: qasigiannguit.
# Processing Record 75 of Set 1: salalah.
# Processing Record 76 of Set 1: cidreira.
# Processing Record 77 of Set 1: upernavik.
# Processing Record 78 of Set 1: hilo.
# Processing Record 79 of Set 1: new norfolk.
# Processing Record 80 of Set 1: hasaki.
# Processing Record 81 of Set 1: saint-dizier.
# Processing Record 82 of Set 1: calbuco.
# Processing Record 83 of Set 1: bad driburg.
# Processing Record 84 of Set 1: disna.
# disna not found
# Processing Record 84 of Set 1: tsihombe.
# tsihombe not found
# Processing Record 84 of Set 1: talnakh.
# Processing Record 85 of Set 1: torrington.
# Processing Record 86 of Set 1: satitoa.
# satitoa not found
# Processing Record 86 of Set 1: maceio.
# Processing Record 87 of Set 1: muros.
# Processing Record 88 of Set 1: mar del plata.
# Processing Record 89 of Set 1: tuktoyaktuk.
# Processing Record 90 of Set 1: kailua.
# Processing Record 91 of Set 1: mahibadhoo.
# Processing Record 92 of Set 1: clarence town.
# Processing Record 93 of Set 1: rudnogorsk.
# Processing Record 94 of Set 1: richards bay.
# Processing Record 95 of Set 1: monrovia.
# Processing Record 96 of Set 1: illoqqortoormiut.
# illoqqortoormiut not found
# Processing Record 96 of Set 1: victoria.
# Processing Record 97 of Set 1: inirida.
# Processing Record 98 of Set 1: isangel.
# Processing Record 99 of Set 1: lorengau.
# Processing Record 100 of Set 1: khandbari.
# Processing Record 101 of Set 1: tura.
# Processing Record 102 of Set 1: nome.
# Processing Record 103 of Set 1: narsaq.
# Processing Record 104 of Set 1: gidam.
# Processing Record 105 of Set 1: ubinskoye.
# Processing Record 106 of Set 1: aleksandrov gay.
# Processing Record 107 of Set 1: conceicao do mato dentro.
# Processing Record 108 of Set 1: mayo.
# Processing Record 109 of Set 1: mandera.
# Processing Record 110 of Set 1: vaitupu.
# vaitupu not found
# Processing Record 110 of Set 1: hithadhoo.
# Processing Record 111 of Set 1: sobradinho.
# Processing Record 112 of Set 1: prieska.
# Processing Record 113 of Set 1: olinda.
# Processing Record 114 of Set 1: hualmay.
# Processing Record 115 of Set 1: tual.
# Processing Record 116 of Set 1: namatanai.
# Processing Record 117 of Set 1: sentyabrskiy.
# sentyabrskiy not found
# Processing Record 117 of Set 1: condega.
# Processing Record 118 of Set 1: port blair.
# Processing Record 119 of Set 1: karratha.
# Processing Record 120 of Set 1: nikolskoye.
# Processing Record 121 of Set 1: tecoanapa.
# Processing Record 122 of Set 1: tiksi.
# Processing Record 123 of Set 1: hobart.
# Processing Record 124 of Set 1: souillac.
# Processing Record 125 of Set 1: xining.
# Processing Record 126 of Set 1: sistranda.
# Processing Record 127 of Set 1: lompoc.
# Processing Record 128 of Set 1: wasilla.
# Processing Record 129 of Set 1: praia da vitoria.
# Processing Record 130 of Set 1: mullaitivu.
# mullaitivu not found
# Processing Record 130 of Set 1: brownsville.
# Processing Record 131 of Set 1: chuy.
# Processing Record 132 of Set 1: provideniya.
# Processing Record 133 of Set 1: portland.
# Processing Record 134 of Set 1: bethel.
# Processing Record 135 of Set 1: sao filipe.
# Processing Record 136 of Set 1: luderitz.
# Processing Record 137 of Set 1: najran.
# Processing Record 138 of Set 1: baruun-urt.
# Processing Record 139 of Set 1: ribeira grande.
# Processing Record 140 of Set 1: maldonado.
# Processing Record 141 of Set 1: lolua.
# lolua not found
# Processing Record 141 of Set 1: yeniseysk.
# Processing Record 142 of Set 1: muisne.
# Processing Record 143 of Set 1: pousat.
# pousat not found
# Processing Record 143 of Set 1: jaguey grande.
# Processing Record 144 of Set 1: lebu.
# Processing Record 145 of Set 1: phan rang.
# phan rang not found
# Processing Record 145 of Set 1: tautira.
# Processing Record 146 of Set 1: novoye leushino.
# Processing Record 147 of Set 1: barrow.
# Processing Record 148 of Set 1: grand river south east.
# grand river south east not found
# Processing Record 148 of Set 1: mulanje.
# Processing Record 149 of Set 1: meyungs.
# meyungs not found
# Processing Record 149 of Set 1: bandrele.
# Processing Record 150 of Set 1: palabuhanratu.
# palabuhanratu not found
# Processing Record 150 of Set 1: taolanaro.
# taolanaro not found
# Processing Record 150 of Set 1: east london.
# Processing Record 151 of Set 1: alofi.
# Processing Record 152 of Set 1: walvis bay.
# Processing Record 153 of Set 1: andra.
# Processing Record 154 of Set 1: kavieng.
# Processing Record 155 of Set 1: bensonville.
# Processing Record 156 of Set 1: saskylakh.
# Processing Record 157 of Set 1: inta.
# Processing Record 158 of Set 1: mapimi.
# Processing Record 159 of Set 1: ramshir.
# Processing Record 160 of Set 1: la ronge.
# Processing Record 161 of Set 1: mabaruma.
# Processing Record 162 of Set 1: ilulissat.
# Processing Record 163 of Set 1: saint george.
# Processing Record 164 of Set 1: khatanga.
# Processing Record 165 of Set 1: broken hill.
# Processing Record 166 of Set 1: zwijndrecht.
# Processing Record 167 of Set 1: saint-philippe.
# Processing Record 168 of Set 1: bathsheba.
# Processing Record 169 of Set 1: praia.
# Processing Record 170 of Set 1: dakar.
# Processing Record 171 of Set 1: kerema.
# Processing Record 172 of Set 1: longyearbyen.
# Processing Record 173 of Set 1: ambon.
# Processing Record 174 of Set 1: san onofre.
# Processing Record 175 of Set 1: tongliao.
# Processing Record 176 of Set 1: bubaque.
# Processing Record 177 of Set 1: amapa.
# Processing Record 178 of Set 1: kodiak.
# Processing Record 179 of Set 1: huarmey.
# Processing Record 180 of Set 1: dikson.
# Processing Record 181 of Set 1: alice springs.
# Processing Record 182 of Set 1: muravlenko.
# Processing Record 183 of Set 1: port hardy.
# Processing Record 184 of Set 1: kaitangata.
# Processing Record 185 of Set 1: klaksvik.
# Processing Record 186 of Set 1: abu jubayhah.
# abu jubayhah not found
# Processing Record 186 of Set 1: fortuna.
# Processing Record 187 of Set 1: norman wells.
# Processing Record 188 of Set 1: umm lajj.
# Processing Record 189 of Set 1: wakkanai.
# Processing Record 190 of Set 1: abu kamal.
# Processing Record 191 of Set 1: port elizabeth.
# Processing Record 192 of Set 1: guia lopes da laguna.
# Processing Record 193 of Set 1: mmabatho.
# Processing Record 194 of Set 1: barabai.
# Processing Record 195 of Set 1: boyabat.
# Processing Record 196 of Set 1: coihaique.
# Processing Record 197 of Set 1: khor.
# Processing Record 198 of Set 1: arraial do cabo.
# Processing Record 199 of Set 1: kadykchan.
# kadykchan not found
# Processing Record 199 of Set 1: mahebourg.
# Processing Record 200 of Set 1: faya.
# Processing Record 201 of Set 1: banapur.
# Processing Record 202 of Set 1: victoria point.
# Processing Record 203 of Set 1: funadhoo.
# Processing Record 204 of Set 1: thunder bay.
# Processing Record 205 of Set 1: crystal lake.
# Processing Record 206 of Set 1: abbeville.
# Processing Record 207 of Set 1: qaanaaq.
# Processing Record 208 of Set 1: we.
# we not found
# Processing Record 208 of Set 1: bairiki.
# bairiki not found
# Processing Record 208 of Set 1: san rafael.
# Processing Record 209 of Set 1: emba.
# Processing Record 210 of Set 1: lavrentiya.
# Processing Record 211 of Set 1: pingzhuang.
# pingzhuang not found
# Processing Record 211 of Set 1: whitehorse.
# Processing Record 212 of Set 1: yaan.
# Processing Record 213 of Set 1: atar.
# Processing Record 214 of Set 1: nuyo.
# Processing Record 215 of Set 1: samarai.
# Processing Record 216 of Set 1: padang.
# Processing Record 217 of Set 1: halalo.
# halalo not found
# Processing Record 217 of Set 1: springdale.
# Processing Record 218 of Set 1: naukot.
# Processing Record 219 of Set 1: sabzevar.
# Processing Record 220 of Set 1: marzuq.
# Processing Record 221 of Set 1: qaqortoq.
# Processing Record 222 of Set 1: samusu.
# samusu not found
# Processing Record 222 of Set 1: darhan.
# Processing Record 223 of Set 1: georgetown.
# Processing Record 224 of Set 1: barentsburg.
# barentsburg not found
# Processing Record 224 of Set 1: wonthaggi.
# Processing Record 225 of Set 1: campoverde.
# Processing Record 226 of Set 1: te anau.
# Processing Record 227 of Set 1: vila franca do campo.
# Processing Record 228 of Set 1: babanusah.
# babanusah not found
# Processing Record 228 of Set 1: anadyr.
# Processing Record 229 of Set 1: saint-pierre.
# Processing Record 230 of Set 1: hailin.
# Processing Record 231 of Set 1: dunedin.
# Processing Record 232 of Set 1: asau.
# asau not found
# Processing Record 232 of Set 1: yumen.
# Processing Record 233 of Set 1: mackay.
# Processing Record 234 of Set 1: charters towers.
# Processing Record 235 of Set 1: saint-georges.
# Processing Record 236 of Set 1: solsvik.
# solsvik not found
# Processing Record 236 of Set 1: drumheller.
# Processing Record 237 of Set 1: awbari.
# Processing Record 238 of Set 1: christchurch.
# Processing Record 239 of Set 1: san luis.
# Processing Record 240 of Set 1: winnemucca.
# Processing Record 241 of Set 1: bonavista.
# Processing Record 242 of Set 1: chom bung.
# chom bung not found
# Processing Record 242 of Set 1: luena.
# Processing Record 243 of Set 1: meulaboh.
# Processing Record 244 of Set 1: geraldton.
# Processing Record 245 of Set 1: kodinsk.
# Processing Record 246 of Set 1: makasar.
# Processing Record 247 of Set 1: ponta delgada.
# Processing Record 248 of Set 1: champerico.
# Processing Record 249 of Set 1: vilyuysk.
# Processing Record 250 of Set 1: torres.
# Processing Record 251 of Set 1: nemuro.
# Processing Record 252 of Set 1: road town.
# Processing Record 253 of Set 1: igrim.
# Processing Record 254 of Set 1: rawson.
# Processing Record 255 of Set 1: san joaquin.
# Processing Record 256 of Set 1: ostrovnoy.
# Processing Record 257 of Set 1: yar-sale.
# Processing Record 258 of Set 1: westport.
# Processing Record 259 of Set 1: tipitapa.
# Processing Record 260 of Set 1: nuuk.
# Processing Record 261 of Set 1: dubti.
# Processing Record 262 of Set 1: totness.
# Processing Record 263 of Set 1: manica.
# Processing Record 264 of Set 1: zhuhai.
# Processing Record 265 of Set 1: sola.
# Processing Record 266 of Set 1: lima.
# Processing Record 267 of Set 1: makokou.
# Processing Record 268 of Set 1: tanjong sepat.
# tanjong sepat not found
# Processing Record 268 of Set 1: ust-kamchatsk.
# ust-kamchatsk not found
# Processing Record 268 of Set 1: bandarbeyla.
# Processing Record 269 of Set 1: hearst.
# Processing Record 270 of Set 1: valparaiso.
# Processing Record 271 of Set 1: mayskiy.
# Processing Record 272 of Set 1: kalabo.
# Processing Record 273 of Set 1: athabasca.
# Processing Record 274 of Set 1: hihifo.
# hihifo not found
# Processing Record 274 of Set 1: san jose.
# Processing Record 275 of Set 1: calabozo.
# Processing Record 276 of Set 1: ornskoldsvik.
# Processing Record 277 of Set 1: vernon.
# Processing Record 278 of Set 1: mao.
# Processing Record 279 of Set 1: staryy oskol.
# Processing Record 280 of Set 1: asfi.
# asfi not found
# Processing Record 280 of Set 1: kaili.
# Processing Record 281 of Set 1: manokwari.
# Processing Record 282 of Set 1: kahului.
# Processing Record 283 of Set 1: marang.
# marang not found
# Processing Record 283 of Set 1: mys shmidta.
# mys shmidta not found
# Processing Record 283 of Set 1: jumla.
# Processing Record 284 of Set 1: hay river.
# Processing Record 285 of Set 1: yulara.
# Processing Record 286 of Set 1: altay.
# Processing Record 287 of Set 1: halifax.
# Processing Record 288 of Set 1: adre.
# Processing Record 289 of Set 1: kamaishi.
# Processing Record 290 of Set 1: bismarck.
# Processing Record 291 of Set 1: dingle.
# Processing Record 292 of Set 1: pilao arcado.
# pilao arcado not found
# Processing Record 292 of Set 1: irtyshskiy.
# Processing Record 293 of Set 1: rio grande.
# Processing Record 294 of Set 1: altus.
# Processing Record 295 of Set 1: telciu.
# Processing Record 296 of Set 1: banda aceh.
# Processing Record 297 of Set 1: kieta.
# Processing Record 298 of Set 1: la rioja.
# Processing Record 299 of Set 1: las tunas.
# Processing Record 300 of Set 1: poum.
# Processing Record 301 of Set 1: sinnamary.
# Processing Record 302 of Set 1: gazni.
# gazni not found
# Processing Record 302 of Set 1: listvyanskiy.
# Processing Record 303 of Set 1: esperance.
# Processing Record 304 of Set 1: itoman.
# Processing Record 305 of Set 1: dwarka.
# Processing Record 306 of Set 1: mount gambier.
# Processing Record 307 of Set 1: firminopolis.
# Processing Record 308 of Set 1: sitka.
# Processing Record 309 of Set 1: azimur.
# azimur not found
# Processing Record 309 of Set 1: purgstall.
# Processing Record 310 of Set 1: ketchikan.
# Processing Record 311 of Set 1: ruatoria.
# ruatoria not found
# Processing Record 311 of Set 1: yenagoa.
# Processing Record 312 of Set 1: ocu.
# Processing Record 313 of Set 1: warqla.
# warqla not found
# Processing Record 313 of Set 1: marsa matruh.
# Processing Record 314 of Set 1: bambous virieux.
# Processing Record 315 of Set 1: palora.
# Processing Record 316 of Set 1: cocobeach.
# Processing Record 317 of Set 1: umm ruwabah.
# umm ruwabah not found
# Processing Record 317 of Set 1: cayenne.
# Processing Record 318 of Set 1: tyukhtet.
# Processing Record 319 of Set 1: wanning.
# Processing Record 320 of Set 1: leningradskiy.
# Processing Record 321 of Set 1: chernyshevskiy.
# Processing Record 322 of Set 1: ilebo.
# Processing Record 323 of Set 1: tikhvin.
# Processing Record 324 of Set 1: shingu.
# Processing Record 325 of Set 1: limbang.
# Processing Record 326 of Set 1: skegness.
# Processing Record 327 of Set 1: vanimo.
# Processing Record 328 of Set 1: burnie.
# Processing Record 329 of Set 1: lixourion.
# Processing Record 330 of Set 1: arroyo.
# Processing Record 331 of Set 1: beian.
# Processing Record 332 of Set 1: tazovskiy.
# Processing Record 333 of Set 1: wageningen.
# Processing Record 334 of Set 1: santa fe.
# Processing Record 335 of Set 1: katsuura.
# Processing Record 336 of Set 1: batagay-alyta.
# Processing Record 337 of Set 1: kropotkin.
# Processing Record 338 of Set 1: abu dhabi.
# Processing Record 339 of Set 1: fairbanks.
# Processing Record 340 of Set 1: grafton.
# Processing Record 341 of Set 1: buraydah.
# Processing Record 342 of Set 1: aktau.
# Processing Record 343 of Set 1: port lincoln.
# Processing Record 344 of Set 1: kirkenaer.
# Processing Record 345 of Set 1: faanui.
# Processing Record 346 of Set 1: samalaeulu.
# samalaeulu not found
# Processing Record 346 of Set 1: pisco.
# Processing Record 347 of Set 1: macomb.
# Processing Record 348 of Set 1: presidencia roque saenz pena.
# Processing Record 349 of Set 1: jiblah.
# Processing Record 350 of Set 1: kaeo.
# Processing Record 351 of Set 1: asgabat.
# asgabat not found
# Processing Record 351 of Set 1: kalmar.
# Processing Record 352 of Set 1: aasiaat.
# Processing Record 353 of Set 1: sao jose da coroa grande.
# Processing Record 354 of Set 1: port hedland.
# Processing Record 355 of Set 1: juneau.
# Processing Record 356 of Set 1: lengshuitan.
# Processing Record 357 of Set 1: kungurtug.
# Processing Record 358 of Set 1: fare.
# Processing Record 359 of Set 1: moose factory.
# Processing Record 360 of Set 1: san cristobal.
# Processing Record 361 of Set 1: louisbourg.
# louisbourg not found
# Processing Record 361 of Set 1: mataram.
# Processing Record 362 of Set 1: aflu.
# aflu not found
# Processing Record 362 of Set 1: mudbidri.
# Processing Record 363 of Set 1: hailar.
# Processing Record 364 of Set 1: pozoblanco.
# Processing Record 365 of Set 1: nabire.
# Processing Record 366 of Set 1: beloha.
# Processing Record 367 of Set 1: mandalgovi.
# Processing Record 368 of Set 1: bilma.
# Processing Record 369 of Set 1: noumea.
# Processing Record 370 of Set 1: inhambane.
# Processing Record 371 of Set 1: lake city.
# Processing Record 372 of Set 1: barsovo.
# Processing Record 373 of Set 1: grand centre.
# grand centre not found
# Processing Record 373 of Set 1: sucre.
# Processing Record 374 of Set 1: nelson bay.
# Processing Record 375 of Set 1: kudahuvadhoo.
# Processing Record 376 of Set 1: kholmogory.
# Processing Record 377 of Set 1: baculin.
# Processing Record 378 of Set 1: kurduvadi.
# Processing Record 379 of Set 1: tullahoma.
# Processing Record 380 of Set 1: pacific grove.
# Processing Record 381 of Set 1: newport.
# Processing Record 382 of Set 1: zhanaozen.
# Processing Record 383 of Set 1: jacqueville.
# Processing Record 384 of Set 1: petropavlovsk-kamchatskiy.
# Processing Record 385 of Set 1: beyla.
# Processing Record 386 of Set 1: zyryanka.
# Processing Record 387 of Set 1: rio gallegos.
# Processing Record 388 of Set 1: bonthe.
# Processing Record 389 of Set 1: bobrovka.
# Processing Record 390 of Set 1: axim.
# Processing Record 391 of Set 1: iqaluit.
# Processing Record 392 of Set 1: khandyga.
# Processing Record 393 of Set 1: touros.
# Processing Record 394 of Set 1: merauke.
# Processing Record 395 of Set 1: saldanha.
# Processing Record 396 of Set 1: cuiluan.
# Processing Record 397 of Set 1: auki.
# Processing Record 398 of Set 1: puerto carreno.
# Processing Record 399 of Set 1: clyde river.
# Processing Record 400 of Set 1: san fernando.
# Processing Record 401 of Set 1: san lazaro.
# Processing Record 402 of Set 1: barawe.
# barawe not found
# Processing Record 402 of Set 1: viedma.
# Processing Record 403 of Set 1: laguna.
# Processing Record 404 of Set 1: kemijarvi.
# kemijarvi not found
# Processing Record 404 of Set 1: kathmandu.
# Processing Record 405 of Set 1: veraval.
# Processing Record 406 of Set 1: damietta.
# Processing Record 407 of Set 1: lazaro cardenas.
# Processing Record 408 of Set 1: ahipara.
# Processing Record 409 of Set 1: japura.
# Processing Record 410 of Set 1: hirara.
# Processing Record 411 of Set 1: reggio di calabria.
# Processing Record 412 of Set 1: ewa beach.
# Processing Record 413 of Set 1: doctor pedro p. pena.
# doctor pedro p. pena not found
# Processing Record 413 of Set 1: kroderen.
# kroderen not found
# Processing Record 413 of Set 1: kirkland lake.
# Processing Record 414 of Set 1: buariki.
# buariki not found
# Processing Record 414 of Set 1: taiobeiras.
# Processing Record 415 of Set 1: beni suef.
# Processing Record 416 of Set 1: talbahat.
# Processing Record 417 of Set 1: iwaki.
# Processing Record 418 of Set 1: buin.
# Processing Record 419 of Set 1: bengkulu.
# bengkulu not found
# Processing Record 419 of Set 1: magdagachi.
# Processing Record 420 of Set 1: gretna.
# Processing Record 421 of Set 1: yankton.
# Processing Record 422 of Set 1: ranong.
# Processing Record 423 of Set 1: desaguadero.
# Processing Record 424 of Set 1: nanortalik.
# Processing Record 425 of Set 1: erenhot.
# Processing Record 426 of Set 1: baykalsk.
# Processing Record 427 of Set 1: egvekinot.
# Processing Record 428 of Set 1: payo.
# Processing Record 429 of Set 1: sisimiut.
# Processing Record 430 of Set 1: bhanjanagar.
# Processing Record 431 of Set 1: sharkan.
# Processing Record 432 of Set 1: nizwa.
# Processing Record 433 of Set 1: flinders.
# Processing Record 434 of Set 1: loreto.
# Processing Record 435 of Set 1: cam pha.
# cam pha not found
# Processing Record 435 of Set 1: soltsy.
# Processing Record 436 of Set 1: roma.
# Processing Record 437 of Set 1: moscow.
# Processing Record 438 of Set 1: los chiles.
# Processing Record 439 of Set 1: castrillon.
# Processing Record 440 of Set 1: lata.
# Processing Record 441 of Set 1: siuri.
# Processing Record 442 of Set 1: koudougou.
# Processing Record 443 of Set 1: gigmoto.
# Processing Record 444 of Set 1: hovd.
# Processing Record 445 of Set 1: attawapiskat.
# attawapiskat not found
# Processing Record 445 of Set 1: gulshat.
# gulshat not found
# Processing Record 445 of Set 1: peniche.
# Processing Record 446 of Set 1: malwan.
# malwan not found
# Processing Record 446 of Set 1: lahij.
# Processing Record 447 of Set 1: kavaratti.
# Processing Record 448 of Set 1: apastovo.
# Processing Record 449 of Set 1: falealupo.
# falealupo not found
# Processing Record 449 of Set 1: abu samrah.
# Processing Record 450 of Set 1: osakarovka.
# Processing Record 451 of Set 1: umm kaddadah.
# Processing Record 452 of Set 1: benito juarez.
# Processing Record 453 of Set 1: codrington.
# Processing Record 454 of Set 1: gamba.
# Processing Record 455 of Set 1: mount isa.
# Processing Record 456 of Set 1: adrar.
# Processing Record 457 of Set 1: caravelas.
# Processing Record 458 of Set 1: shenjiamen.
# Processing Record 459 of Set 1: katherine.
# Processing Record 460 of Set 1: shu.
# Processing Record 461 of Set 1: avera.
# Processing Record 462 of Set 1: qandahar.
# qandahar not found
# Processing Record 462 of Set 1: berlevag.
# Processing Record 463 of Set 1: choma.
# Processing Record 464 of Set 1: bend.
# Processing Record 465 of Set 1: imeni poliny osipenko.
# Processing Record 466 of Set 1: bratsk.
# Processing Record 467 of Set 1: kapit.
# Processing Record 468 of Set 1: aswan.
# Processing Record 469 of Set 1: tubuala.
# Processing Record 470 of Set 1: grand-lahou.
# Processing Record 471 of Set 1: ishigaki.
# Processing Record 472 of Set 1: nove sedlo.
# Processing Record 473 of Set 1: urumqi.
# urumqi not found
# Processing Record 473 of Set 1: toliary.
# toliary not found
# Processing Record 473 of Set 1: nyangao.
# Processing Record 474 of Set 1: shimoda.
# Processing Record 475 of Set 1: chara.
# Processing Record 476 of Set 1: nantucket.
# Processing Record 477 of Set 1: mitu.
# Processing Record 478 of Set 1: cozumel.
# cozumel not found
# Processing Record 478 of Set 1: kinkala.
# Processing Record 479 of Set 1: yuci.
# Processing Record 480 of Set 1: assare.
# Processing Record 481 of Set 1: anzio.
# Processing Record 482 of Set 1: barquisimeto.
# Processing Record 483 of Set 1: bonfim.
# Processing Record 484 of Set 1: talara.
# Processing Record 485 of Set 1: aksarka.
# Processing Record 486 of Set 1: warwick.
# Processing Record 487 of Set 1: maningrida.
# Processing Record 488 of Set 1: vao.
# Processing Record 489 of Set 1: hami.
# Processing Record 490 of Set 1: sungaipenuh.
# Processing Record 491 of Set 1: pangnirtung.
# Processing Record 492 of Set 1: ekibastuz.
# Processing Record 493 of Set 1: bambanglipuro.
# Processing Record 494 of Set 1: kamina.
# Processing Record 495 of Set 1: davila.
# Processing Record 496 of Set 1: bangassou.
# Processing Record 497 of Set 1: milpitas.
# Processing Record 498 of Set 1: tumannyy.
# tumannyy not found
# Processing Record 498 of Set 1: mandurah.
# Processing Record 499 of Set 1: kokkola.
# Processing Record 500 of Set 1: saeby.
# Processing Record 501 of Set 1: cheremshan.
# Processing Record 502 of Set 1: staryy biser.
# staryy biser not found
# Processing Record 502 of Set 1: itaueira.
# Processing Record 503 of Set 1: lieksa.
# Processing Record 504 of Set 1: penzance.
# Processing Record 505 of Set 1: dawei.
# Processing Record 506 of Set 1: nioro.
# Processing Record 507 of Set 1: bredy.
# Processing Record 508 of Set 1: oranjemund.
# Processing Record 509 of Set 1: cabo san lucas.
# Processing Record 510 of Set 1: prince rupert.
# Processing Record 511 of Set 1: anjiang.
# Processing Record 512 of Set 1: hambantota.
# Processing Record 513 of Set 1: tigil.
# Processing Record 514 of Set 1: sicamous.
# Processing Record 515 of Set 1: navapur.
# navapur not found
# Processing Record 515 of Set 1: santa cruz.
# Processing Record 516 of Set 1: maragogi.
# Processing Record 517 of Set 1: wamba.
# Processing Record 518 of Set 1: zapolyarnyy.
# Processing Record 519 of Set 1: along.
# Processing Record 520 of Set 1: pleasantville.
# Processing Record 521 of Set 1: gao.
# Processing Record 522 of Set 1: boddam.
# Processing Record 523 of Set 1: srednekolymsk.
# Processing Record 524 of Set 1: whitecourt.
# Processing Record 525 of Set 1: otane.
# Processing Record 526 of Set 1: ginda.
# Processing Record 527 of Set 1: kruisfontein.
# Processing Record 528 of Set 1: sindor.
# Processing Record 529 of Set 1: kokstad.
# Processing Record 530 of Set 1: ambulu.
# Processing Record 531 of Set 1: alenquer.
# Processing Record 532 of Set 1: tilichiki.
# Processing Record 533 of Set 1: kalevala.
# Processing Record 534 of Set 1: zhezkazgan.
# Processing Record 535 of Set 1: amarwara.
# Processing Record 536 of Set 1: kuche.
# kuche not found
# Processing Record 536 of Set 1: ola.
# Processing Record 537 of Set 1: plettenberg bay.
# Processing Record 538 of Set 1: paragominas.
# Processing Record 539 of Set 1: glamoc.
# Processing Record 540 of Set 1: nicoya.
# Processing Record 541 of Set 1: tiarei.
# Processing Record 542 of Set 1: stavern.
# Processing Record 543 of Set 1: harper.
# Processing Record 544 of Set 1: srandakan.
# Processing Record 545 of Set 1: mount abu.
# Processing Record 546 of Set 1: fort nelson.
# done

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# #Making a DataFrame to hold informations pulled from API
weather_df = pd.DataFrame(columns =["Name"
                                    ,"Cloudiness"
                                    ,"Country"
                                    ,"Date"
                                    ,"Humidity"
                                    ,"Latitude"
                                    ,"Longitude"
                                    ,"Max Temp"
                                    ,"Wind Speed"])
weather_df["Name"] = name
weather_df["Cloudiness"] = clouds
weather_df["Country"] = country
weather_df["Date"] = date
weather_df["Humidity"] = humidity
weather_df["Latitude"] = lat
weather_df["Longitude"] = lon
weather_df["Max Temp"] = temp_max
weather_df["Wind Speed"] = wind_speed

weather_df.head()
# Out:
#           Name  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0        Conde           6      BR  1561327304        96    -11.81     -37.61
# 1       Avarua          46      CK  1561327265        53    -21.21    -159.78
# 2  Yellowknife          75      CA  1561327245        56     62.45    -114.38
# 3  Pak Phanang         100      TH  1561327206        86      8.35     100.20
# 4   Coahuayana          73      MX  1561327306        48     18.62    -100.35
#
#    Max Temp  Wind Speed
# 0     70.29        3.49
# 1     75.20       19.46
# 2     71.60        6.93
# 3     77.33        6.26
# 4     92.02        2.95

# %%
weather_df.to_csv("Weather.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
print("Observation concerning maximum temperature:")
print("The closer to the equator the higher the likely maximum temperature. At this time of year the highest temperatures are")
print("in the northern hemisphere")
weather_df.plot.scatter("Latitude"
                        , "Max Temp"
                       , c = "blue")

plt.title("Latitude vs Max Temperature (6/23/19)")
plt.grid()
plt.savefig("Latitude vs Max Temperature.png")
# Out:
# Observation concerning maximum temperature:
# The closer to the equator the higher the likely maximum temperature. At this time of year the highest temperatures are
# in the northern hemisphere

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
print("Observation concenring latitude and humidity:")
print("There is no discernable correlation between latitude and humidity")
weather_df.plot.scatter("Latitude"
                        , "Humidity"
                       , c = "midnightblue")

plt.title("Latitude vs Humidity (6/23/19)")
plt.grid()
plt.savefig("Latitude vs Humidity.png")
# Out:
# Observation concenring latitude and humidity:
# There is no discernable correlation between latitude and humidity

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
print("Observation concenring latitude and cloudiness:")
print("There is no discernable correlation between latitude and cloudiness")
weather_df.plot.scatter("Latitude"
                        , "Cloudiness"
                        , c="dimgrey")

plt.title("Latitude vs Cloudiness (6/23/19)")
plt.grid()
plt.savefig("Latitude vs Cloudiness.png")
# Out:
# Observation concenring latitude and cloudiness:
# There is no discernable correlation between latitude and cloudiness

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
print("Observation concenring latitude and wind speed:")
print("There is no discernable correlation between latitude and wind speed")
weather_df.plot.scatter("Latitude"
                        , "Wind Speed"
                        , c="Indigo")

plt.title("Latitude vs Wind Speed (6/23/19)")
plt.grid()
plt.savefig("Latitude vs Wind Speed.png")
# Out:
# Observation concenring latitude and wind speed:
# There is no discernable correlation between latitude and wind speed
